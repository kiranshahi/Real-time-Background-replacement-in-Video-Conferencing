jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000344.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000345.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000346.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000350.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000351.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000352.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000353.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000354.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000355.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000356.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000359.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000360.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000361.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000362.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000363.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000364.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000366.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000367.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000368.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000370.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000371.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000373.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000374.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000375.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000376.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000377.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000378.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000379.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000380.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000381.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000382.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000383.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000384.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000385.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000386.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000387.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000389.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000390.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000391.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000392.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000393.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000394.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000395.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000396.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000397.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000398.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000399.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000401.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000402.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000404.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000405.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000406.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000407.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000408.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000410.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000412.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000413.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000415.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000416.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000417.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000418.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000419.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000420.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000421.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000422.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000423.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000424.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000425.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000426.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000427.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000429.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000430.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000431.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000433.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000434.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000435.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000436.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000437.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000438.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000440.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000441.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000442.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000443.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000444.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000445.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000446.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000447.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000448.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000450.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000451.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000452.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000453.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000456.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000457.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000458.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000459.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000460.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000461.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000462.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000465.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000466.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000467.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000468.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000469.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000470.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000471.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000472.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000473.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000474.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000475.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000476.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000477.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000478.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000480.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0000481.jpg',
# ...
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001086.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001087.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001088.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001089.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001091.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001093.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001095.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001096.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001097.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001098.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001099.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001100.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001102.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001103.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001107.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001108.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001109.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001110.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001111.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001113.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001114.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001115.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001116.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001117.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001118.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001119.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001121.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001122.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001123.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001124.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001125.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001126.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001128.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001129.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001130.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001131.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001132.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001134.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001136.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001137.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001138.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001139.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001142.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001143.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001144.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001145.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001146.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001148.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001149.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001150.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001154.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001155.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001156.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001157.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001161.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001162.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001163.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001164.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001167.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001168.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001169.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001170.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001171.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001173.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001174.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001176.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001177.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001178.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001179.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001180.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001181.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001183.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001184.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001186.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001188.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001189.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001190.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001192.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001193.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001194.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001196.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001198.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001199.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001200.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001201.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001202.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001203.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001204.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001205.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001206.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001207.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001208.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001209.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001210.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001211.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001212.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001213.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001214.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001216.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001219.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001220.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001221.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001222.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001223.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001224.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001225.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001226.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001227.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001228.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001229.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001230.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001232.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001234.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001235.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001236.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001237.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001239.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001240.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001241.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001242.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001245.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001246.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001247.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001248.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001249.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001250.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001251.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001252.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001253.jpg',
#  './instance-level-human-parsing/instance-level_human_parsing/instance-level_human_parsing/Training\\Images\\0001254.jpg']

# %%
def read_image(image_path, mask=False):
    image = tf.io.read_file(image_path)
    if mask:
        image = tf.image.decode_png(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
    else:
        image = tf.image.decode_png(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
        image = image / 127.5 - 1
    return image

# %%
def load_data(image_list, mask_list):
    image = read_image(image_list)
    mask = read_image(mask_list, mask=True)
    return image, mask

# %%
def data_generator(image_list, mask_list):
    dataset = tf.data.Dataset.from_tensor_slices((image_list, mask_list))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset

# %%
train_dataset = data_generator(train_images, train_masks)
val_dataset = data_generator(val_images, val_masks)

# %%
train_dataset
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(4, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset element_spec=(TensorSpec(shape=(4, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 512, 512, 1), dtype=tf.float32, name=None))>
# Val Dataset: <BatchDataset element_spec=(TensorSpec(shape=(4, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
def convolution_block(
    block_input,
    num_filters=256,
    kernel_size=3,
    dilation_rate=1,
    padding="same",
    use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)

# %%
def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)
    
    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)
    
    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

# %%
def DeeplabV3Plus(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, image_size, 3))
    resnet50 = keras.applications.ResNet50(
        weights="imagenet", include_top=False, input_tensor=model_input
    )
    x = resnet50.get_layer("conv4_block6_2_relu").output
    x = DilatedSpatialPyramidPooling(x)
    
    input_a = layers.UpSampling2D(
        size = (image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)
    
    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    return keras.Model(inputs=model_input, outputs=model_output)

model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 518, 518, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 256, 256, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 256, 256, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 258, 258, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 128, 128, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 64  4160        ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 128, 128, 25  16640       ['pool1_pool[0][0]']
#                                 6)
#
#  conv2_block1_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_add (Add)         (None, 128, 128, 25  0           ['conv2_block1_0_bn[0][0]',
#                                 6)                                'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 128, 128, 25  0           ['conv2_block1_add[0][0]']
#                                 6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 64  16448       ['conv2_block1_out[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#
#  conv2_block2_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       6)
#  conv2_block2_add (Add)         (None, 128, 128, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 128, 128, 25  0           ['conv2_block2_add[0][0]']
#                                 6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 64  16448       ['conv2_block2_out[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_2_bn[0][0]']
#  n)                             )
#
#  conv2_block3_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block3_2_relu[0][0]']
#                                 6)
#
#  conv2_block3_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block3_add (Add)         (None, 128, 128, 25  0           ['conv2_block2_out[0][0]',
#                                 6)                                'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 128, 128, 25  0           ['conv2_block3_add[0][0]']
#                                 6)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 64, 64, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 64, 64, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#  conv3_block2_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 64, 64, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 64, 64, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 64, 64, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 32, 32, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 32, 32, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 32, 32, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 32, 32, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 32, 32, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 32, 32, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  average_pooling2d (AveragePool  (None, 1, 1, 256)   0           ['conv4_block6_2_relu[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 1, 1, 256)    65792       ['average_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 1, 256)   1024        ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 256)  65536       ['conv4_block6_2_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  tf.nn.relu (TFOpLambda)        (None, 1, 1, 256)    0           ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 256)  0           ['tf.nn.relu[0][0]']
#
#  tf.nn.relu_1 (TFOpLambda)      (None, 32, 32, 256)  0           ['batch_normalization_1[0][0]']
#
#  tf.nn.relu_2 (TFOpLambda)      (None, 32, 32, 256)  0           ['batch_normalization_2[0][0]']
#
#  tf.nn.relu_3 (TFOpLambda)      (None, 32, 32, 256)  0           ['batch_normalization_3[0][0]']
#
#  tf.nn.relu_4 (TFOpLambda)      (None, 32, 32, 256)  0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 1280  0           ['up_sampling2d[0][0]',
#                                 )                                 'tf.nn.relu_1[0][0]',
#                                                                   'tf.nn.relu_2[0][0]',
#                                                                   'tf.nn.relu_3[0][0]',
#                                                                   'tf.nn.relu_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  327680      ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 48  3072        ['conv2_block3_2_relu[0][0]']
#                                 )
#
#  tf.nn.relu_5 (TFOpLambda)      (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 48  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['tf.nn.relu_5[0][0]']
#                                 6)
#
#  tf.nn.relu_6 (TFOpLambda)      (None, 128, 128, 48  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 30  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'tf.nn.relu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 25  700416      ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_7[0][0]']
#  rmalization)                   6)
#
#  tf.nn.relu_7 (TFOpLambda)      (None, 128, 128, 25  0           ['batch_normalization_7[0][0]']
#                                 6)
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 25  589824      ['tf.nn.relu_7[0][0]']
#                                 6)
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_8[0][0]']
#  rmalization)                   6)
#
#  tf.nn.relu_8 (TFOpLambda)      (None, 128, 128, 25  0           ['batch_normalization_8[0][0]']
#                                 6)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 512, 512, 25  0          ['tf.nn.relu_8[0][0]']
#                                 6)
#
#  conv2d_9 (Conv2D)              (None, 512, 512, 20  5140        ['up_sampling2d_2[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 11,857,236
# Trainable params: 11,824,500
# Non-trainable params: 32,736
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training

# %%
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss=loss,
    metrics=["accuracy"],
)
history = model.fit(train_dataset, validation_data=val_dataset, epochs=25)
# Out:
# Epoch 1/25
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [14], in <cell line: 7>()
#       1 loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#       2 model.compile(
#       3     optimizer=keras.optimizers.Adam(learning_rate=0.001),
#       4     loss=loss,
#       5     metrics=["accuracy"],
#       6 )
# ----> 7 history = model.fit(train_dataset, validation_data=val_dataset, epochs=25)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model/up_sampling2d_2/resize/ResizeBilinear' defined at (most recent call last):
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\traitlets\config\application.py", line 976, in launch_instance
#       app.start()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\asyncio\base_events.py", line 600, in run_forever
#       self._run_once()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\asyncio\base_events.py", line 1896, in _run_once
#       handle._run()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\kiran\AppData\Local\Temp\ipykernel_384\2681676647.py", line 7, in <cell line: 7>
#       history = model.fit(train_dataset, validation_data=val_dataset, epochs=25)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 889, in train_step
#       y_pred = self(x, training=True)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 490, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py", line 1014, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py", line 458, in call
#       return self._run_internal_graph(
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py", line 596, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py", line 1014, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\layers\reshaping\up_sampling2d.py", line 129, in call
#       return backend.resize_images(
#     File "C:\Users\kiran\anaconda3\envs\tf\lib\site-packages\keras\backend.py", line 3432, in resize_images
#       x = tf.image.resize(x, new_shape, method=interpolations[interpolation])
# Node: 'model/up_sampling2d_2/resize/ResizeBilinear'
# OOM when allocating tensor with shape[4,512,512,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/up_sampling2d_2/resize/ResizeBilinear}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_13067]

# %%
plt.plot(history.history["loss"])
plt.title("Training Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 plt.plot(history.history["loss"])
#       2 plt.title("Training Loss")
#       3 plt.ylabel("loss")
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history["accuracy"])
plt.title("Training Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 plt.plot(history.history["accuracy"])
#       2 plt.title("Training Accuracy")
#       3 plt.ylabel("accuracy")
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history["val_loss"])
plt.title("Validation Loss")
plt.ylabel("val_loss")
plt.xlabel("epoch")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 plt.plot(history.history["val_loss"])
#       2 plt.title("Validation Loss")
#       3 plt.ylabel("val_loss")
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history["val_accuracy"])
plt.title("Validation Accuracy")
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.show()
