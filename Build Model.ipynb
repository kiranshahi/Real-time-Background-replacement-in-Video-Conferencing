# %%
import tensorflow as tf

from tensorflow.keras.layers import Activation, MaxPool2D, Concatenate, ConvLSTM2D, Dropout, TimeDistributed, Reshape
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, BatchNormalization, Add, UpSampling2D, ConvLSTM2D
from tensorflow.keras.models import Model

from tensorflow.keras.applications import MobileNetV3Large, MobileNetV2
import numpy as np

# %%
time_steps = 30

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(filters=num_filters, kernel_size=3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    N =  np.int32(x.shape[2])
    x = Reshape(target_shape=(1, N, N, num_filters))(x)
    x = ConvLSTM2D(filters = num_filters, kernel_size=(3, 3), padding='same', return_sequences=False, go_backwards=True, kernel_initializer='he_normal' )(x)
    return x

# %%
def upsample_block(inputs, skip_features, num_filters):
    x = UpSampling2D(interpolation='bilinear')(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    x = Dropout(0.3)(x)    
    return x

# %%
def LRASPP(x, out_channels: int):
    x1 = Conv2D(out_channels, 1, use_bias=False)(x)
    x1 = BatchNormalization(momentum=0.1, epsilon=1e-5)(x1)
    x1 = Activation('relu')(x)
    
    x2 = Conv2D(out_channels, 1, use_bias=False, activation='sigmoid')(tf.reduce_mean(x, axis=[1, 2], keepdims=True))
    return x1 * x2

# %%
def output_block(inputs):
    x = Conv2D(3, (1,1), 1, 'same', use_bias=False)(inputs)
    x = BatchNormalization(momentum=0.1, epsilon=1e-5)(x)
    x = Activation('relu')(x)
    x = Conv2D(3, (1,1), 1, 'same', use_bias=False)(inputs)
    x = BatchNormalization(momentum=0.1, epsilon=1e-5)(x)
    x = Activation('relu')(x)
    return x

# %%
def get_model():
    inputs = Input(shape=(560, 560, 3), name='input')
    encoder = MobileNetV3Large(input_tensor=inputs, weights="imagenet", include_top=False)
    
    for layer in encoder.layers:
        layer.trainable = False
    
    
    #inputs = Input(shape=(30, 256, 256, 3))
    
    # Encoder
    e1 = encoder.get_layer('input').output      # (None, 560, 560, 3)
    e2 = encoder.get_layer('re_lu_2').output    # (None, 280, 280, 64)
    e3 = encoder.get_layer('re_lu_6').output    # (None, 140, 140, 72)
    e4 = encoder.get_layer('re_lu_15').output   # (None, 70, 70, 240)
    
    # Bridge
    b4 = encoder.get_layer('re_lu_29').output   #(None, 35, 35, 672)
    
    # lraspp = LRASPP(e4, 672)
    
    ### Decoder
    d1 = upsample_block(b4, e4, 672)
    d2 = upsample_block(d1, e3, 256)
    d3 = upsample_block(d2, e2, 128)
    d4 = upsample_block(d3, e1, 64)
    
    # Output
    outputs = output_block(d4)
    outputs = Conv2D(1, (1,1), 1, 'same', activation='sigmoid')(outputs)
    
    return Model(inputs, outputs)

# %%
model = get_model()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 560, 560, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 560, 560, 3)  0           ['input[0][0]']
#
#  Conv (Conv2D)                  (None, 280, 280, 16  432         ['rescaling[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 280, 280, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add (TFOpLamb  (None, 280, 280, 16  0          ['Conv/BatchNorm[0][0]']
#  da)                            )
#
#  re_lu (ReLU)                   (None, 280, 280, 16  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 280, 280, 16  0           ['re_lu[0][0]']
#                                 )
#
#  multiply (Multiply)            (None, 280, 280, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 280, 280, 16  144        ['multiply[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 280, 280, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_1 (ReLU)                 (None, 280, 280, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 280, 280, 16  256        ['re_lu_1[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 280, 280, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 280, 280, 16  0           ['multiply[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 280, 280, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 280, 280, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_2 (ReLU)                 (None, 280, 280, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 281, 281, 64  0          ['re_lu_2[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 140, 140, 64  576        ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                  )                                ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 140, 140, 64  256        ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)     )                                ']
#
#  re_lu_3 (ReLU)                 (None, 140, 140, 64  0           ['expanded_conv_1/depthwise/Batch
#                                 )                                Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 140, 140, 24  1536       ['re_lu_3[0][0]']
#  D)                             )
#
#  expanded_conv_1/project/BatchN  (None, 140, 140, 24  96         ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)       )
#
#  expanded_conv_2/expand (Conv2D  (None, 140, 140, 72  1728       ['expanded_conv_1/project/BatchNo
#  )                              )                                rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 140, 140, 72  288        ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_4 (ReLU)                 (None, 140, 140, 72  0           ['expanded_conv_2/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 140, 140, 72  648        ['re_lu_4[0][0]']
#  thwiseConv2D)                  )
#
#  expanded_conv_2/depthwise/Batc  (None, 140, 140, 72  288        ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)     )                                ']
#
#  re_lu_5 (ReLU)                 (None, 140, 140, 72  0           ['expanded_conv_2/depthwise/Batch
#                                 )                                Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 140, 140, 24  1728       ['re_lu_5[0][0]']
#  D)                             )
#
#  expanded_conv_2/project/BatchN  (None, 140, 140, 24  96         ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)       )
#
#  expanded_conv_2/Add (Add)      (None, 140, 140, 24  0           ['expanded_conv_1/project/BatchNo
#                                 )                                rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 140, 140, 72  1728       ['expanded_conv_2/Add[0][0]']
#  )                              )
#
#  expanded_conv_3/expand/BatchNo  (None, 140, 140, 72  288        ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_6 (ReLU)                 (None, 140, 140, 72  0           ['expanded_conv_3/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 143, 143, 72  0          ['re_lu_6[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_3/depthwise (Dep  (None, 70, 70, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 70, 70, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_7 (ReLU)                 (None, 70, 70, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_7[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 1, 1, 72)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 72)    0           ['re_lu_8[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 70, 70, 72)  0           ['re_lu_7[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 70, 70, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 70, 70, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 70, 70, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 70, 70, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_9 (ReLU)                 (None, 70, 70, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 70, 70, 120)  3000       ['re_lu_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 70, 70, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_10 (ReLU)                (None, 70, 70, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_11[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 70, 70, 120)  0          ['re_lu_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 70, 70, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 70, 70, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 70, 70, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 70, 70, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 70, 70, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_12 (ReLU)                (None, 70, 70, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 70, 70, 120)  3000       ['re_lu_12[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 70, 70, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_13 (ReLU)                (None, 70, 70, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_13[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_14 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_14[0][0]']
#  )
#
#  expanded_conv_5/squeeze_excite  (None, 70, 70, 120)  0          ['re_lu_13[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 70, 70, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 70, 70, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 70, 70, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 70, 70, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 70, 70, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 70, 70, 240)  0          ['expanded_conv_6/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_15 (ReLU)                (None, 70, 70, 240)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 70, 70, 240)  0          ['re_lu_15[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 70, 70, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 71, 71, 240)  0          ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 35, 35, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 35, 35, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 35, 35, 240)  0          ['expanded_conv_6/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_16 (ReLU)                (None, 35, 35, 240)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 35, 35, 240)  0          ['re_lu_16[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 35, 35, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 35, 35, 80)  19200       ['multiply_2[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 35, 35, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 35, 35, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 35, 35, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 35, 35, 200)  0          ['expanded_conv_7/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_17 (ReLU)                (None, 35, 35, 200)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 35, 35, 200)  0          ['re_lu_17[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 35, 35, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 35, 35, 200)  1800       ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 35, 35, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 35, 35, 200)  0          ['expanded_conv_7/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_18 (ReLU)                (None, 35, 35, 200)  0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 35, 35, 200)  0          ['re_lu_18[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 35, 35, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 35, 35, 80)  16000       ['multiply_4[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 35, 35, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 35, 35, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 35, 35, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 35, 35, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 35, 35, 184)  0          ['expanded_conv_8/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 35, 35, 184)  0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 35, 35, 184)  0          ['re_lu_19[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 35, 35, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 35, 35, 184)  1656       ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 35, 35, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 35, 35, 184)  0          ['expanded_conv_8/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 35, 35, 184)  0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 35, 35, 184)  0          ['re_lu_20[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 35, 35, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 35, 35, 80)  14720       ['multiply_6[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 35, 35, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 35, 35, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 35, 35, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 35, 35, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 35, 35, 184)  0          ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_21 (ReLU)                (None, 35, 35, 184)  0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 35, 35, 184)  0          ['re_lu_21[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 35, 35, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 35, 35, 184)  1656       ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 35, 35, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_11 (TFOpL  (None, 35, 35, 184)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_22 (ReLU)                (None, 35, 35, 184)  0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 35, 35, 184)  0          ['re_lu_22[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 35, 35, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 35, 35, 80)  14720       ['multiply_8[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 35, 35, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 35, 35, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 35, 35, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 35, 35, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 35, 35, 480)  0          ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_23 (ReLU)                (None, 35, 35, 480)  0           ['tf.__operators__.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 35, 35, 480)  0          ['re_lu_23[0][0]']
#  a)
#
#  multiply_9 (Multiply)          (None, 35, 35, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 35, 35, 480)  4320       ['multiply_9[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 35, 35, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 35, 35, 480)  0          ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_24 (ReLU)                (None, 35, 35, 480)  0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 35, 35, 480)  0          ['re_lu_24[0][0]']
#  a)
#
#  multiply_10 (Multiply)         (None, 35, 35, 480)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_13[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_10[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
# ...
#  expanded_conv_11/depthwise/Bat  (None, 35, 35, 672)  2688       ['expanded_conv_11/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 35, 35, 672)  0          ['expanded_conv_11/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_27 (ReLU)                (None, 35, 35, 672)  0           ['tf.__operators__.add_16[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 35, 35, 672)  0          ['re_lu_27[0][0]']
#  a)
#
#  multiply_12 (Multiply)         (None, 35, 35, 672)  0           ['expanded_conv_11/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_16[0][0]']
#
#  expanded_conv_11/squeeze_excit  (None, 1, 1, 672)   0           ['multiply_12[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_11/squeeze_excit  (None, 1, 1, 168)   113064      ['expanded_conv_11/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_11/squeeze_excit  (None, 1, 1, 168)   0           ['expanded_conv_11/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_11/squeeze_excit  (None, 1, 1, 672)   113568      ['expanded_conv_11/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 1, 1, 672)   0           ['expanded_conv_11/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_28 (ReLU)                (None, 1, 1, 672)    0           ['tf.__operators__.add_17[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 1, 1, 672)   0           ['re_lu_28[0][0]']
#  a)
#
#  expanded_conv_11/squeeze_excit  (None, 35, 35, 672)  0          ['multiply_12[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_17[0][0]']
#
#  expanded_conv_11/project (Conv  (None, 35, 35, 112)  75264      ['expanded_conv_11/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_11/project/Batch  (None, 35, 35, 112)  448        ['expanded_conv_11/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_11/Add (Add)     (None, 35, 35, 112)  0           ['expanded_conv_10/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_11/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_12/expand (Conv2  (None, 35, 35, 672)  75264      ['expanded_conv_11/Add[0][0]']
#  D)
#  expanded_conv_12/expand/BatchN  (None, 35, 35, 672)  2688       ['expanded_conv_12/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_18 (TFOpL  (None, 35, 35, 672)  0          ['expanded_conv_12/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_29 (ReLU)                (None, 35, 35, 672)  0           ['tf.__operators__.add_18[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 70, 70, 672)  0           ['re_lu_29[0][0]']
#
#  concatenate (Concatenate)      (None, 70, 70, 912)  0           ['up_sampling2d[0][0]',
#                                                                   're_lu_15[0][0]']
#
#  conv2d (Conv2D)                (None, 70, 70, 672)  5516448     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 70, 70, 672)  2688       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 70, 70, 672)  0           ['batch_normalization[0][0]']
#
#  reshape (Reshape)              (None, 1, 70, 70, 6  0           ['activation[0][0]']
#                                 72)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 70, 70, 672)  32516736    ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 70, 70, 672)  0           ['conv_lstm2d[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 140, 140, 67  0          ['dropout[0][0]']
#                                 2)
#
#  concatenate_1 (Concatenate)    (None, 140, 140, 74  0           ['up_sampling2d_1[0][0]',
#                                 4)                                're_lu_6[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 140, 140, 25  1714432     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_1 (BatchNo  (None, 140, 140, 25  1024       ['conv2d_1[0][0]']
#  rmalization)                   6)
#
#  activation_1 (Activation)      (None, 140, 140, 25  0           ['batch_normalization_1[0][0]']
#                                 6)
#
#  reshape_1 (Reshape)            (None, 1, 140, 140,  0           ['activation_1[0][0]']
#                                  256)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 140, 140, 25  4719616     ['reshape_1[0][0]']
#                                 6)
#
#  dropout_1 (Dropout)            (None, 140, 140, 25  0           ['conv_lstm2d_1[0][0]']
#                                 6)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 280, 280, 25  0          ['dropout_1[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 280, 280, 32  0           ['up_sampling2d_2[0][0]',
#                                 0)                                're_lu_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 280, 280, 12  368768      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 280, 280, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 280, 280, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  reshape_2 (Reshape)            (None, 1, 280, 280,  0           ['activation_2[0][0]']
#                                  128)
#
#  conv_lstm2d_2 (ConvLSTM2D)     (None, 280, 280, 12  1180160     ['reshape_2[0][0]']
#                                 8)
#
#  dropout_2 (Dropout)            (None, 280, 280, 12  0           ['conv_lstm2d_2[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 560, 560, 12  0          ['dropout_2[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 560, 560, 13  0           ['up_sampling2d_3[0][0]',
#                                 1)                                'input[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 560, 560, 64  75520       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 560, 560, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 560, 560, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  reshape_3 (Reshape)            (None, 1, 560, 560,  0           ['activation_3[0][0]']
#                                  64)
#
#  conv_lstm2d_3 (ConvLSTM2D)     (None, 560, 560, 64  295168      ['reshape_3[0][0]']
#                                 )
#
#  dropout_3 (Dropout)            (None, 560, 560, 64  0           ['conv_lstm2d_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 560, 560, 3)  192         ['dropout_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 560, 560, 3)  12         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 560, 560, 3)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 560, 560, 1)  4           ['activation_5[0][0]']
#
# ==================================================================================================
# Total params: 47,273,128
# Trainable params: 46,389,290
# Non-trainable params: 883,838
# __________________________________________________________________________________________________
